# %%
#Scatter plots
#Lineplot
#Boxplot
#Pie_Chart
#Donut_Chart

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
import plotly.express as px
fig=px.scatter(x=[0,1,2,3,4,5,6],y=[0,10,20,30,40,50,60])
fig.show()
# Out:
# <div>                            <div id="693b3a9e-c6b8-4f12-88c5-c8cd5f83e69c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("693b3a9e-c6b8-4f12-88c5-c8cd5f83e69c")) {                    Plotly.newPlot(                        "693b3a9e-c6b8-4f12-88c5-c8cd5f83e69c",                        [{"hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[0,1,2,3,4,5,6],"xaxis":"x","y":[0,10,20,30,40,50,60],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[
# ...

# %%
df=px.data.iris()
fig=px.scatter(df,x='sepal_width',y='sepal_length')
fig.show()
# Out:
# <div>                            <div id="78660946-362f-45c9-85d2-68673526c30a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("78660946-362f-45c9-85d2-68673526c30a")) {                    Plotly.newPlot(                        "78660946-362f-45c9-85d2-68673526c30a",                        [{"hovertemplate":"sepal_width=%{x}<br>sepal_length=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[3.5,3.0,3.2,3.1,3.6,3.9,3.4,3.4,2.9,3.1,3.7,3.4,3.0,3.0,4.0,4.4,3.9,3.5,3.8,3.8,3.4,3.7,3.6,3.3,3.4,3.0,3.4,3.5,3.4,3.2,3.1,3.4,4.1,4.2,3.1,3.2,3.5,3.1,3.0,3.4,3.5,2.3,3.2,3.5,3.8,3.0,3.8,3.2,3.7,3.3,3.2,3.2,3.1,2.3,2.8,2.8,3.3,2.4,2.9,2.7,2.0,3.0,2.2,2.9,2.9,3.
# ...

# %%
df=px.data.iris()
fig=px.scatter(df,x='sepal_width',y='sepal_length',color='species',size='petal_length')
fig.show()
# Out:
# <div>                            <div id="32cd1cec-e182-4a91-96d7-9c1968bdbc64" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("32cd1cec-e182-4a91-96d7-9c1968bdbc64")) {                    Plotly.newPlot(                        "32cd1cec-e182-4a91-96d7-9c1968bdbc64",                        [{"hovertemplate":"species=setosa<br>sepal_width=%{x}<br>sepal_length=%{y}<br>petal_length=%{marker.size}<extra></extra>","legendgroup":"setosa","marker":{"color":"#636efa","size":[1.4,1.4,1.3,1.5,1.4,1.7,1.4,1.5,1.4,1.5,1.5,1.6,1.4,1.1,1.2,1.5,1.3,1.4,1.7,1.5,1.7,1.5,1.0,1.7,1.9,1.6,1.6,1.5,1.4,1.6,1.6,1.5,1.5,1.4,1.5,1.2,1.3,1.5,1.3,1.5,1.3,1.3,1.3,1.6,1.9,1.4,1.6,1.4,1.5,1.4],"sizemode":"area","sizeref":0.01725,"symbol":"circle"},"mode":"markers","name":"setosa
# ...

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species  species_id
# 0           5.1          3.5           1.4          0.2  setosa           1
# 1           4.9          3.0           1.4          0.2  setosa           1
# 2           4.7          3.2           1.3          0.2  setosa           1
# 3           4.6          3.1           1.5          0.2  setosa           1
# 4           5.0          3.6           1.4          0.2  setosa           1

# %%
df=px.data.iris()
fig=px.scatter(df,x='sepal_length',y='sepal_width',color='species')
fig.show()
# Out:
# <div>                            <div id="8cff35e3-1fee-4429-bd43-76e4e0d2a34c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8cff35e3-1fee-4429-bd43-76e4e0d2a34c")) {                    Plotly.newPlot(                        "8cff35e3-1fee-4429-bd43-76e4e0d2a34c",                        [{"hovertemplate":"species=setosa<br>sepal_length=%{x}<br>sepal_width=%{y}<extra></extra>","legendgroup":"setosa","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"setosa","orientation":"v","showlegend":true,"x":[5.1,4.9,4.7,4.6,5.0,5.4,4.6,5.0,4.4,4.9,5.4,4.8,4.8,4.3,5.8,5.7,5.4,5.1,5.7,5.1,5.4,5.1,4.6,5.1,4.8,5.0,5.0,5.2,5.2,4.7,4.8,5.4,5.2,5.5,4.9,5.0,5.5,4.9,4.4,5.1,5.0,4.5,4.4,5.0,5.1,4.8,5.1,4.6,5.3,5.0],"xaxis":"x","y":[3.5,3.0,3.2,3.1
# ...

# %%
#Line plots

# %%
import numpy as np
t=np.linspace(0,2*np.pi,100)
fig=px.line(x=t,y=np.cos(t),labels={'x':'t','t':'cos(t)'})
fig.show()
# Out:
# <div>                            <div id="34ff6967-c0e0-440f-a575-e2c615b2997a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("34ff6967-c0e0-440f-a575-e2c615b2997a")) {                    Plotly.newPlot(                        "34ff6967-c0e0-440f-a575-e2c615b2997a",                        [{"hovertemplate":"t=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":[0.0,0.06346651825433926,0.12693303650867852,0.1903995547630178,0.25386607301735703,0.3173325912716963,0.3807991095260356,0.4442656277803748,0.5077321460347141,0.5711986642890533,0.6346651825433925,0.6981317007977318,0.7615982190520711,0.8250647373064104,0.88853
# ...

# %%
df=px.data.gapminder().query("continent=='Oceania'")
df
# Out:
#           country continent  year  lifeExp       pop    gdpPercap iso_alpha  \
# 60      Australia   Oceania  1952   69.120   8691212  10039.59564       AUS
# 61      Australia   Oceania  1957   70.330   9712569  10949.64959       AUS
# 62      Australia   Oceania  1962   70.930  10794968  12217.22686       AUS
# 63      Australia   Oceania  1967   71.100  11872264  14526.12465       AUS
# 64      Australia   Oceania  1972   71.930  13177000  16788.62948       AUS
# 65      Australia   Oceania  1977   73.490  14074100  18334.19751       AUS
# 66      Australia   Oceania  1982   74.740  15184200  19477.00928       AUS
# 67      Australia   Oceania  1987   76.320  16257249  21888.88903       AUS
# 68      Australia   Oceania  1992   77.560  17481977  23424.76683       AUS
# 69      Australia   Oceania  1997   78.830  18565243  26997.93657       AUS
# 70      Australia   Oceania  2002   80.370  19546792  30687.75473       AUS
# ...

# %%
fig=px.line(df,x='year',y='lifeExp',labels={'x':'Year','y':'life Expectancy'},color='country')
fig.show()
# Out:
# <div>                            <div id="46335add-77bf-4d32-be66-5654be005878" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("46335add-77bf-4d32-be66-5654be005878")) {                    Plotly.newPlot(                        "46335add-77bf-4d32-be66-5654be005878",                        [{"hovertemplate":"country=Australia<br>year=%{x}<br>lifeExp=%{y}<extra></extra>","legendgroup":"Australia","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Australia","orientation":"v","showlegend":true,"x":[1952,1957,1962,1967,1972,1977,1982,1987,1992,1997,2002,2007],"xaxis":"x","y":[69.12,70.33,70.93,71.1,71.93,73.49,74.74,76.32,77.56,78.83,80.37,81.235],"yaxis":"y","type":"scatter"},{"hovertemplate":"country=New Zea
# ...

# %%
fig=px.line(df,x='year',y='lifeExp',labels={'x':'Year','y':'life Expectancy'},color='country',markers=True)
fig.show()
# Out:
# <div>                            <div id="22957cff-504e-4225-9362-c9ce9cd9cebe" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("22957cff-504e-4225-9362-c9ce9cd9cebe")) {                    Plotly.newPlot(                        "22957cff-504e-4225-9362-c9ce9cd9cebe",                        [{"hovertemplate":"country=Australia<br>year=%{x}<br>lifeExp=%{y}<extra></extra>","legendgroup":"Australia","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"markers+lines","name":"Australia","orientation":"v","showlegend":true,"x":[1952,1957,1962,1967,1972,1977,1982,1987,1992,1997,2002,2007],"xaxis":"x","y":[69.12,70.33,70.93,71.1,71.93,73.49,74.74,76.32,77.56,78.83,80.37,81.235],"yaxis":"y","type":"scatter"},{"hovertemplate":"country
# ...

# %%
df=px.data.stocks()
df.head()
# Out:
#          date      GOOG      AAPL      AMZN        FB      NFLX      MSFT
# 0  2018-01-01  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 1  2018-01-08  1.018172  1.011943  1.061881  0.959968  1.053526  1.015988
# 2  2018-01-15  1.032008  1.019771  1.053240  0.970243  1.049860  1.020524
# 3  2018-01-22  1.066783  0.980057  1.140676  1.016858  1.307681  1.066561
# 4  2018-01-29  1.008773  0.917143  1.163374  1.018357  1.273537  1.040708

# %%
fig=px.line(df,x='date',y='GOOG')
fig.show()
# Out:
# <div>                            <div id="eeb81776-662f-4156-a890-270854f9c81b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("eeb81776-662f-4156-a890-270854f9c81b")) {                    Plotly.newPlot(                        "eeb81776-662f-4156-a890-270854f9c81b",                        [{"hovertemplate":"date=%{x}<br>GOOG=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2018-01-01","2018-01-08","2018-01-15","2018-01-22","2018-01-29","2018-02-05","2018-02-12","2018-02-19","2018-02-26","2018-03-05","2018-03-12","2018-03-19","2018-03-26","2018-04-02","2018-04-09","2018-04-16","2018-04-23","2018-04-30","2018-05-07","2018-05
# ...

# %%
import pandas as pd
df=pd.DataFrame(dict(x=[1,2,3,4],y=[2,4,6,8]))
df
# Out:
#    x  y
# 0  1  2
# 1  2  4
# 2  3  6
# 3  4  8

# %%
fig=px.line(df,x='x',y='y',title='Unsorted_input')
fig.show()
# Out:
# <div>                            <div id="83e05563-978d-4189-bfc8-03db8abc68e5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("83e05563-978d-4189-bfc8-03db8abc68e5")) {                    Plotly.newPlot(                        "83e05563-978d-4189-bfc8-03db8abc68e5",                        [{"hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":[1,2,3,4],"xaxis":"x","y":[2,4,6,8],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f
# ...

# %%
df=pd.DataFrame(dict(x=[1,3,4,2],y=[1,2,3,4]))
df=df.sort_values(by='x')
fig=px.line(df,x='x',y='y',title='Sorted-input')
fig.show()
# Out:
# <div>                            <div id="ae688910-6ce9-4f29-8791-20c2c9133709" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ae688910-6ce9-4f29-8791-20c2c9133709")) {                    Plotly.newPlot(                        "ae688910-6ce9-4f29-8791-20c2c9133709",                        [{"hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":[1,2,3,4],"xaxis":"x","y":[1,4,2,3],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f
# ...

# %%
import plotly.express as px
import pandas as pd
import numpy as np

df=px.data.tips()
fig=px.box(df,x='time',y='total_bill')
fig.show()
# Out:
# <div>                            <div id="1fd56392-8d8e-4a42-a99e-2c910e6dd331" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1fd56392-8d8e-4a42-a99e-2c910e6dd331")) {                    Plotly.newPlot(                        "1fd56392-8d8e-4a42-a99e-2c910e6dd331",                        [{"alignmentgroup":"True","hovertemplate":"time=%{x}<br>total_bill=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["Dinner","Dinner","Dinner","Dinner","Dinner","Dinner","Dinner","Dinner","Dinner","Dinner","Dinner","Dinner","Dinner","Dinner","Dinner","Dinner","Dinner","Dinner","Dinner","Dinner","Dinner","Dinner","Dinner","Dinner","Dinner","Dinner","Dinner","Dinne
# ...

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df=px.data.tips()
fig=px.box(df,x='time',y='total_bill',color='day')
fig.show()
# Out:
# <div>                            <div id="cbfee018-be1f-47f1-8564-60b485ab342b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cbfee018-be1f-47f1-8564-60b485ab342b")) {                    Plotly.newPlot(                        "cbfee018-be1f-47f1-8564-60b485ab342b",                        [{"alignmentgroup":"True","hovertemplate":"day=Sun<br>time=%{x}<br>total_bill=%{y}<extra></extra>","legendgroup":"Sun","marker":{"color":"#636efa"},"name":"Sun","notched":false,"offsetgroup":"Sun","orientation":"v","showlegend":true,"x":["Dinner","Dinner","Dinner","Dinner","Dinner","Dinner","Dinner","Dinner","Dinner","Dinner","Dinner","Dinner","Dinner","Dinner","Dinner","Dinner","Dinner","Dinner","Dinner","Dinner","Dinner","Dinner","Dinner","Dinner","Dinner","Dinn
# ...

# %%
import plotly.graph_objects as go

labels = ['Oxygen','Hydrogen','Carbon_Dioxide','Nitrogen']
values = [4500, 2500, 1053, 500]

# Use `hole` to create a donut-like pie chart
fig = go.Figure(data=[go.Pie(labels=labels, values=values, hole=.3)])
fig.show()
# Out:
# <div>                            <div id="a3ca17aa-2c92-43b7-9645-07004c9fde43" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a3ca17aa-2c92-43b7-9645-07004c9fde43")) {                    Plotly.newPlot(                        "a3ca17aa-2c92-43b7-9645-07004c9fde43",                        [{"hole":0.3,"labels":["Oxygen","Hydrogen","Carbon_Dioxide","Nitrogen"],"values":[4500,2500,1053,500],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"
# ...

# %%
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
# Preview the dataset
# df.head()

# Create the graph
category=['Hardware','Software','Services']
spending=[350000,450000,200000]
fig=go.Figure(data=[go.Pie(labels=category,values=spending,hole=0.3,marker_colors=['navy', 'gray', 'teal'])])
fig.show()
# Out:
# <div>                            <div id="13088332-16ce-4613-a941-012150e1a2bb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("13088332-16ce-4613-a941-012150e1a2bb")) {                    Plotly.newPlot(                        "13088332-16ce-4613-a941-012150e1a2bb",                        [{"hole":0.3,"labels":["Hardware","Software","Services"],"marker":{"colors":["navy","gray","teal"]},"values":[350000,450000,200000],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"]
# ...

# %%
import matplotlib.pyplot as plt
import plotly.graph_objects as go
# Preview the dataset
# df.head()

# Create the graph
plt.figure(figsize=(8,8))
platform=['PC','Consoles','Mobile']
market_share=[35,40,25]
fig=go.Figure(data=[go.Pie(labels=platform,values=market_share,hole=0.3,marker=dict(colors=['sienna','rosybrown','tan']))])
fig.show()
# Out:
# <div>                            <div id="49a7449d-bb79-40ee-98c8-47fac874b3fe" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("49a7449d-bb79-40ee-98c8-47fac874b3fe")) {                    Plotly.newPlot(                        "49a7449d-bb79-40ee-98c8-47fac874b3fe",                        [{"hole":0.3,"labels":["PC","Consoles","Mobile"],"marker":{"colors":["sienna","rosybrown","tan"]},"values":[35,40,25],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666
# ...

# %%
import matplotlib.pyplot as plt
import plotly.graph_objects as go
# Preview the dataset
# df.head()

# Create the graph
plt.figure(figsize=(8,8))
platform=['PC','Consoles','Mobile']
market_share=[35,40,25]
fig=go.Figure(data=[go.Pie(labels=platform,values=market_share,marker=dict(colors=['sienna','rosybrown','tan']))])
fig.show()
# Out:
# <div>                            <div id="2e0c475c-73ac-4bb7-8660-95c8d11efc1f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2e0c475c-73ac-4bb7-8660-95c8d11efc1f")) {                    Plotly.newPlot(                        "2e0c475c-73ac-4bb7-8660-95c8d11efc1f",                        [{"labels":["PC","Consoles","Mobile"],"marker":{"colors":["sienna","rosybrown","tan"]},"values":[35,40,25],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed
# ...

# %%
import matplotlib.pyplot as plt
import plotly.graph_objects as go
# Preview the dataset
# df.head()

# Create the graph
plt.figure(figsize=(8,8))
dept=['Administration','Human Resources	','IT Services']
office_space=[350,200,450]
fig=go.Figure(data=[go.Pie(labels=dept,values=office_space,marker=dict(colors=['goldenrod','lightblue','thistle']))])
fig.show()
# Out:
# <div>                            <div id="04658471-d0a7-4303-a73d-4fc3ceac6b85" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("04658471-d0a7-4303-a73d-4fc3ceac6b85")) {                    Plotly.newPlot(                        "04658471-d0a7-4303-a73d-4fc3ceac6b85",                        [{"labels":["Administration","Human Resources\t","IT Services"],"marker":{"colors":["goldenrod","lightblue","thistle"]},"values":[350,200,450],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556
# ...

# %% [markdown]
# import matplotlib.pyplot as plt
# import plotly.graph_objects as go
#
# #Preview the dataset
# df.head()
#
# #Create the graph
# plt.figure(figsize=(8,8))
# labels=['Residential','Commercial','Industrial']
# values=[300,200,500]
# fig=go.Figure(data=[go.Pie(labels,values,marker=dict(colors=['turquoise','khaki','tomato']))])
# #fig=go.Figure(data=[go.Pie(labels=dept,values=office_space,marker=dict(colors=['goldenrod','lightblue','thistle']))])
#
# fig.show()

# %%
import matplotlib.pyplot as plt

# Preview the dataset
# df.head()

# Create the graph
import plotly.graph_objects as go
plt.figure(figsize=(10, 6))
labels=['Brand A','Brand B','Brand C']
values=[500,300,200]
fig=go.Figure(data=[go.Pie(labels=labels,values=values,marker=dict(colors=['gold','silver','bronze']))])
fig.show()
# Out:
# <div>                            <div id="1470926f-1ddd-469a-b3b4-cfbe2fee66d2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1470926f-1ddd-469a-b3b4-cfbe2fee66d2")) {                    Plotly.newPlot(                        "1470926f-1ddd-469a-b3b4-cfbe2fee66d2",                        [{"labels":["Brand A","Brand B","Brand C"],"marker":{"colors":["gold","silver","bronze"]},"values":[500,300,200],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.666666666666666
# ...

# %%
import matplotlib.pyplot as plt
import plotly.express as px
# Preview the dataset
# df.head()

# Create the graph
# import plotly.graph_objects as go
plt.figure(figsize=(10, 6))
labels=['Brand A','Brand B','Brand C']
values=[500,300,200]
fig=px.bar(x=labels,y=values,color=['gold','silver','#cd7f32'])
fig.show()
# Out:
# <div>                            <div id="f1829180-d14d-4977-938c-da89195ee87a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f1829180-d14d-4977-938c-da89195ee87a")) {                    Plotly.newPlot(                        "f1829180-d14d-4977-938c-da89195ee87a",                        [{"alignmentgroup":"True","hovertemplate":"color=gold<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"gold","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"gold","offsetgroup":"gold","orientation":"v","showlegend":true,"textposition":"auto","x":["Brand A"],"xaxis":"x","y":[500],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=silver<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"silver","marker":{"color":"#EF553B","patte
# ...

# %% [markdown]
# import matplotlib.pyplot as plt
# import plotly.express as px
# import plotly.graph_objects as go
# #Preview the dataset
# #df_temperatures.head()
#
# #Create the graph
# plt.figure(figsize=(10, 5))
# plt.plot(df_temperatures['city_a'],color='skyblue')
# plt.plot(df_temperatures['city_b'],color='coral')
# plt.plot(df_temperatures['city_c'],color='limegreen')
# plt.grid(True)
# plt.show()
